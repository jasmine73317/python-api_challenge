# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 629

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
weather_df = pd.DataFrame({"City": cities})
weather_df
# Out:
#              City
# 0            hilo
# 1          avarua
# 2         rikitea
# 3         bintulu
# 4    saint george
# ..            ...
# 624      waingapu
# 625       kokkola
# 626        rincon
# 627       hoquiam
# 628      belmonte
#
# [629 rows x 1 columns]

# %%
weather_df["Cloudiness"]= ""
weather_df["Country"]= ""
weather_df["Date"]= ""
weather_df["Humidity"]= ""
weather_df["Lat"]= ""
weather_df["Lng"]= ""
weather_df["Max Temp"]= ""
weather_df["Wind Speed"]= ""

weather_df.head()
# Out:
#            City Cloudiness Country Date Humidity Lat Lng Max Temp Wind Speed
# 0          hilo
# 1        avarua
# 2       rikitea
# 3       bintulu
# 4  saint george

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"


parameters = {"units": units,
             "appid": "ca033fb144bdbefbb8ef8453ce2bc91c"}

print("Beginning Data Retrieval")
print("-----------------------------")

for index, row in weather_df.iterrows():
    parameters["q"] = row["City"]
    response = requests.get(url, params=parameters).json()
    
    try:        
        weather_df.loc[index, "Cloudiness"] = response["clouds"]["all"]
        weather_df.loc[index, "Country"] = response["sys"]["country"]
        weather_df.loc[index, "Date"] = response["dt"]
        weather_df.loc[index, "Humidity"] = response["main"]["humidity"]
        weather_df.loc[index, "Lat"] = response["coord"]["lat"]
        weather_df.loc[index, "Lng"] = response["coord"]["lon"]
        weather_df.loc[index, "Max Temp"] = response["main"]["temp_max"]
        weather_df.loc[index, "Wind Speed"] = response["wind"]["speed"]
        
        print(f"Processing Record {index} | {row['City']}")
              
    except (KeyError, IndexError):
        print("City not found. Skipping...")

print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 0 | hilo
# Processing Record 1 | avarua
# Processing Record 2 | rikitea
# Processing Record 3 | bintulu
# Processing Record 4 | saint george
# City not found. Skipping...
# Processing Record 6 | kapaa
# Processing Record 7 | srednekolymsk
# Processing Record 8 | ushuaia
# Processing Record 9 | saint anthony
# Processing Record 10 | albany
# Processing Record 11 | portland
# Processing Record 12 | hermanus
# Processing Record 13 | new norfolk
# Processing Record 14 | fortuna
# City not found. Skipping...
# Processing Record 16 | saskylakh
# Processing Record 17 | rio gallegos
# Processing Record 18 | upernavik
# Processing Record 19 | port elizabeth
# Processing Record 20 | luderitz
# Processing Record 21 | aguimes
# Processing Record 22 | pavlodar
# Processing Record 23 | butaritari
# City not found. Skipping...
# Processing Record 25 | abu dhabi
# Processing Record 26 | thompson
# Processing Record 27 | san carlos
# Processing Record 28 | zhanakorgan
# Processing Record 29 | port blair
# Processing Record 30 | tuatapere
# Processing Record 31 | bluff
# Processing Record 32 | vaini
# Processing Record 33 | punta arenas
# Processing Record 34 | hasaki
# Processing Record 35 | arraial do cabo
# Processing Record 36 | port hardy
# Processing Record 37 | saint-gaudens
# Processing Record 38 | mataura
# Processing Record 39 | barrow
# Processing Record 40 | lavrentiya
# Processing Record 41 | cravo norte
# Processing Record 42 | kavieng
# Processing Record 43 | dikson
# Processing Record 44 | silifke
# City not found. Skipping...
# Processing Record 46 | tura
# Processing Record 47 | posse
# Processing Record 48 | veles
# Processing Record 49 | torbay
# Processing Record 50 | pisco
# Processing Record 51 | georgetown
# Processing Record 52 | pokaran
# Processing Record 53 | bathsheba
# Processing Record 54 | mahebourg
# Processing Record 55 | mount gambier
# Processing Record 56 | praia da vitoria
# Processing Record 57 | barra do garcas
# Processing Record 58 | birin
# Processing Record 59 | lodja
# Processing Record 60 | the valley
# Processing Record 61 | beloha
# Processing Record 62 | saint-georges
# Processing Record 63 | leshan
# Processing Record 64 | port alfred
# Processing Record 65 | busselton
# Processing Record 66 | bengkulu
# Processing Record 67 | airai
# Processing Record 68 | vaitape
# Processing Record 69 | cape town
# Processing Record 70 | monrovia
# Processing Record 71 | castro
# Processing Record 72 | salamiyah
# Processing Record 73 | nyimba
# Processing Record 74 | qaanaaq
# Processing Record 75 | aksu
# Processing Record 76 | clyde river
# Processing Record 77 | port moresby
# Processing Record 78 | faanui
# Processing Record 79 | dunedin
# Processing Record 80 | pevek
# Processing Record 81 | sao felix do xingu
# Processing Record 82 | bredasdorp
# Processing Record 83 | katsuura
# Processing Record 84 | tiksi
# Processing Record 85 | geraldton
# Processing Record 86 | hobart
# Processing Record 87 | petropavlovsk-kamchatskiy
# Processing Record 88 | cherskiy
# Processing Record 89 | norman wells
# Processing Record 90 | yellowknife
# City not found. Skipping...
# Processing Record 92 | labuhan
# Processing Record 93 | saint-philippe
# City not found. Skipping...
# Processing Record 95 | shima
# Processing Record 96 | ucluelet
# Processing Record 97 | isangel
# City not found. Skipping...
# Processing Record 99 | ormara
# Processing Record 100 | zharkent
# Processing Record 101 | codajas
# Processing Record 102 | ordu
# Processing Record 103 | misratah
# Processing Record 104 | mar del plata
# Processing Record 105 | bethel
# Processing Record 106 | ribeira grande
# Processing Record 107 | jamestown
# Processing Record 108 | zhigansk
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 111 | fairbanks
# Processing Record 112 | puerto ayora
# Processing Record 113 | severo-kurilsk
# Processing Record 114 | ahipara
# Processing Record 115 | namatanai
# Processing Record 116 | khatanga
# Processing Record 117 | ukiah
# Processing Record 118 | borovoy
# Processing Record 119 | seoul
# Processing Record 120 | jardim
# Processing Record 121 | laramie
# Processing Record 122 | itarema
# City not found. Skipping...
# Processing Record 124 | sandwick
# Processing Record 125 | mossendjo
# City not found. Skipping...
# Processing Record 127 | namibe
# Processing Record 128 | grand gaube
# Processing Record 129 | dali
# Processing Record 130 | springbok
# Processing Record 131 | nikolskoye
# Processing Record 132 | umm lajj
# Processing Record 133 | magadan
# Processing Record 134 | urdoma
# Processing Record 135 | barcelos
# City not found. Skipping...
# Processing Record 137 | jamsa
# City not found. Skipping...
# Processing Record 139 | menongue
# Processing Record 140 | mahibadhoo
# Processing Record 141 | ponta do sol
# Processing Record 142 | sinnamary
# Processing Record 143 | parabel
# Processing Record 144 | uppsala
# Processing Record 145 | saint-augustin
# Processing Record 146 | vilhena
# Processing Record 147 | akyab
# Processing Record 148 | talnakh
# City not found. Skipping...
# Processing Record 150 | xai-xai
# Processing Record 151 | tuktoyaktuk
# Processing Record 152 | ca mau
# Processing Record 153 | cabo san lucas
# City not found. Skipping...
# Processing Record 155 | abu samrah
# Processing Record 156 | chagoda
# Processing Record 157 | victoria
# Processing Record 158 | port lincoln
# Processing Record 159 | mopti
# Processing Record 160 | dingle
# Processing Record 161 | muros
# Processing Record 162 | caicedo
# Processing Record 163 | zelezna ruda
# Processing Record 164 | bani walid
# City not found. Skipping...
# Processing Record 166 | vagur
# Processing Record 167 | lompoc
# Processing Record 168 | luau
# Processing Record 169 | lakes entrance
# Processing Record 170 | najran
# Processing Record 171 | pangnirtung
# Processing Record 172 | chuy
# Processing Record 173 | bemidji
# Processing Record 174 | bath
# Processing Record 175 | tigil
# Processing Record 176 | moron
# Processing Record 177 | hervey bay
# Processing Record 178 | khed brahma
# Processing Record 179 | cidreira
# Processing Record 180 | tsaratanana
# Processing Record 181 | rumonge
# Processing Record 182 | honiara
# Processing Record 183 | carnarvon
# Processing Record 184 | sabinas hidalgo
# Processing Record 185 | praia
# Processing Record 186 | homer
# Processing Record 187 | peleduy
# Processing Record 188 | fujin
# Processing Record 189 | galveston
# Processing Record 190 | kodiak
# Processing Record 191 | were ilu
# City not found. Skipping...
# Processing Record 193 | gold coast
# Processing Record 194 | emba
# Processing Record 195 | adre
# Processing Record 196 | angoche
# Processing Record 197 | mitchell
# Processing Record 198 | sibenik
# Processing Record 199 | port hawkesbury
# Processing Record 200 | meulaboh
# Processing Record 201 | kolvereid
# Processing Record 202 | puerto maldonado
# Processing Record 203 | iqaluit
# Processing Record 204 | alice springs
# Processing Record 205 | anzio
# Processing Record 206 | safaga
# Processing Record 207 | voznesenye
# Processing Record 208 | xuzhou
# Processing Record 209 | mundo nuevo
# City not found. Skipping...
# Processing Record 211 | boa vista
# Processing Record 212 | alta floresta
# Processing Record 213 | fare
# Processing Record 214 | bakchar
# Processing Record 215 | san quintin
# Processing Record 216 | maceio
# Processing Record 217 | tasiilaq
# Processing Record 218 | hualmay
# Processing Record 219 | aseri
# Processing Record 220 | east london
# Processing Record 221 | laguna
# Processing Record 222 | pemberton
# Processing Record 223 | high level
# Processing Record 224 | san rafael
# City not found. Skipping...
# Processing Record 226 | wajir
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 229 | longhua
# Processing Record 230 | leningradskiy
# Processing Record 231 | stornoway
# Processing Record 232 | jalu
# Processing Record 233 | yerofey pavlovich
# Processing Record 234 | zhucheng
# Processing Record 235 | sarkand
# Processing Record 236 | ouadda
# Processing Record 237 | hithadhoo
# Processing Record 238 | tonshayevo
# Processing Record 239 | lida
# Processing Record 240 | los llanos de aridane
# Processing Record 241 | masallatah
# Processing Record 242 | porto belo
# Processing Record 243 | atuona
# Processing Record 244 | san patricio
# Processing Record 245 | necochea
# Processing Record 246 | watsa
# Processing Record 247 | constitucion
# Processing Record 248 | lebu
# Processing Record 249 | luohe
# City not found. Skipping...
# Processing Record 251 | sao jose da coroa grande
# Processing Record 252 | flinders
# Processing Record 253 | piacabucu
# City not found. Skipping...
# Processing Record 255 | coquimbo
# Processing Record 256 | inuvik
# City not found. Skipping...
# Processing Record 258 | calamar
# City not found. Skipping...
# Processing Record 260 | alto araguaia
# Processing Record 261 | wanning
# Processing Record 262 | colares
# Processing Record 263 | socorro
# Processing Record 264 | bambous virieux
# Processing Record 265 | esperance
# City not found. Skipping...
# Processing Record 267 | horki
# Processing Record 268 | balfour
# Processing Record 269 | warmbad
# Processing Record 270 | half moon bay
# Processing Record 271 | pasni
# Processing Record 272 | verkh-usugli
# Processing Record 273 | griffith
# Processing Record 274 | klaksvik
# Processing Record 275 | bilkha
# Processing Record 276 | simpang
# Processing Record 277 | sola
# Processing Record 278 | chifeng
# Processing Record 279 | darhan
# Processing Record 280 | provideniya
# Processing Record 281 | tilichiki
# Processing Record 282 | nuuk
# Processing Record 283 | uvira
# Processing Record 284 | jumla
# Processing Record 285 | nelson bay
# Processing Record 286 | milton
# Processing Record 287 | nagyoroszi
# Processing Record 288 | aiken
# Processing Record 289 | yakeshi
# Processing Record 290 | askos
# Processing Record 291 | lorengau
# Processing Record 292 | rudnichnyy
# Processing Record 293 | ancud
# City not found. Skipping...
# Processing Record 295 | kuryk
# Processing Record 296 | mnogovershinnyy
# Processing Record 297 | baghdad
# Processing Record 298 | syamzha
# Processing Record 299 | xiaoshi
# Processing Record 300 | motygino
# Processing Record 301 | okato
# Processing Record 302 | mazatlan
# Processing Record 303 | mountain home
# Processing Record 304 | berlevag
# City not found. Skipping...
# Processing Record 306 | tyukhtet
# Processing Record 307 | codrington
# Processing Record 308 | arrifes
# Processing Record 309 | lagoa
# Processing Record 310 | puerto narino
# Processing Record 311 | alexandria
# Processing Record 312 | lincoln
# City not found. Skipping...
# Processing Record 314 | manokwari
# Processing Record 315 | tessalit
# Processing Record 316 | te anau
# Processing Record 317 | jiayuguan
# Processing Record 318 | dauphin
# Processing Record 319 | san carlos de bariloche
# Processing Record 320 | alugan
# Processing Record 321 | lata
# Processing Record 322 | sobolevo
# Processing Record 323 | nouadhibou
# Processing Record 324 | klyuchi
# Processing Record 325 | leh
# Processing Record 326 | luanda
# Processing Record 327 | narsaq
# Processing Record 328 | sur
# Processing Record 329 | makakilo city
# Processing Record 330 | yar-sale
# Processing Record 331 | tanout
# Processing Record 332 | vestmanna
# Processing Record 333 | puerto palomas
# Processing Record 334 | abeche
# Processing Record 335 | krasnik
# Processing Record 336 | vadakku valliyur
# Processing Record 337 | acari
# Processing Record 338 | karachi
# Processing Record 339 | cabadiangan
# Processing Record 340 | sao joao da barra
# Processing Record 341 | husavik
# Processing Record 342 | kamenka
# Processing Record 343 | kabanjahe
# Processing Record 344 | jiwani
# Processing Record 345 | tecpan
# Processing Record 346 | hamilton
# Processing Record 347 | richards bay
# Processing Record 348 | nome
# Processing Record 349 | herat
# Processing Record 350 | teguldet
# Processing Record 351 | turukhansk
# Processing Record 352 | christchurch
# Processing Record 353 | taguatinga
# Processing Record 354 | vardo
# Processing Record 355 | kultuk
# City not found. Skipping...
# Processing Record 357 | kahului
# Processing Record 358 | saldanha
# Processing Record 359 | bowmore
# Processing Record 360 | galle
# Processing Record 361 | olinda
# Processing Record 362 | santiago del estero
# Processing Record 363 | wanaka
# Processing Record 364 | reconquista
# Processing Record 365 | kasongo
# Processing Record 366 | turayf
# Processing Record 367 | buraydah
# Processing Record 368 | coihaique
# Processing Record 369 | nemuro
# City not found. Skipping...
# Processing Record 371 | ocosingo
# Processing Record 372 | emerald
# Processing Record 373 | vitim
# Processing Record 374 | urucara
# Processing Record 375 | pincher creek
# Processing Record 376 | cayenne
# Processing Record 377 | ouro preto
# Processing Record 378 | whitehorse
# Processing Record 379 | taonan
# Processing Record 380 | saint-francois
# Processing Record 381 | hay river
# Processing Record 382 | aswan
# Processing Record 383 | bad schwalbach
# Processing Record 384 | ladario
# Processing Record 385 | oshnaviyeh
# Processing Record 386 | ulladulla
# Processing Record 387 | beohari
# Processing Record 388 | dumas
# Processing Record 389 | cap malheureux
# Processing Record 390 | yadrin
# Processing Record 391 | santa maria
# Processing Record 392 | aykhal
# Processing Record 393 | saint-denis
# Processing Record 394 | okoneshnikovo
# Processing Record 395 | wagar
# Processing Record 396 | dryden
# Processing Record 397 | kruisfontein
# Processing Record 398 | antalaha
# Processing Record 399 | makat
# Processing Record 400 | san jose
# Processing Record 401 | nanortalik
# City not found. Skipping...
# Processing Record 403 | jasper
# Processing Record 404 | rawson
# Processing Record 405 | clinton
# Processing Record 406 | hirara
# Processing Record 407 | buala
# Processing Record 408 | bandarbeyla
# Processing Record 409 | camacha
# Processing Record 410 | bolivar
# Processing Record 411 | lajas
# Processing Record 412 | veraval
# Processing Record 413 | ketchikan
# Processing Record 414 | orocue
# Processing Record 415 | bansko
# Processing Record 416 | ixtapa
# Processing Record 417 | kaitangata
# Processing Record 418 | havre-saint-pierre
# Processing Record 419 | martapura
# Processing Record 420 | kiama
# Processing Record 421 | muana
# Processing Record 422 | ostrovnoy
# Processing Record 423 | rocha
# Processing Record 424 | cairns
# Processing Record 425 | adrar
# Processing Record 426 | guisa
# Processing Record 427 | chokurdakh
# Processing Record 428 | la paz
# Processing Record 429 | clermont
# Processing Record 430 | comodoro rivadavia
# Processing Record 431 | florence
# Processing Record 432 | saint-pierre
# Processing Record 433 | sorland
# Processing Record 434 | tornio
# Processing Record 435 | taltal
# Processing Record 436 | palpa
# Processing Record 437 | kloulklubed
# Processing Record 438 | jiangyou
# Processing Record 439 | quatre cocos
# Processing Record 440 | bud
# Processing Record 441 | monster
# Processing Record 442 | mananara
# Processing Record 443 | arona
# Processing Record 444 | linhai
# Processing Record 445 | revda
# Processing Record 446 | cabedelo
# Processing Record 447 | fenelon falls
# Processing Record 448 | hofn
# Processing Record 449 | hambantota
# Processing Record 450 | viedma
# Processing Record 451 | kavaratti
# Processing Record 452 | daru
# Processing Record 453 | gat
# Processing Record 454 | san cristobal
# Processing Record 455 | ust-omchug
# Processing Record 456 | ilulissat
# Processing Record 457 | taoudenni
# Processing Record 458 | concepcion
# Processing Record 459 | alofi
# City not found. Skipping...
# Processing Record 461 | pochutla
# Processing Record 462 | yanam
# Processing Record 463 | wattegama
# Processing Record 464 | korla
# Processing Record 465 | rio grande
# Processing Record 466 | gamba
# Processing Record 467 | qaqortoq
# Processing Record 468 | zeya
# Processing Record 469 | kango
# Processing Record 470 | kalmar
# City not found. Skipping...
# Processing Record 472 | arlit
# Processing Record 473 | aden
# Processing Record 474 | moree
# Processing Record 475 | presidencia roque saenz pena
# Processing Record 476 | sioux lookout
# Processing Record 477 | zhezkazgan
# Processing Record 478 | saint stephen
# Processing Record 479 | san andres
# Processing Record 480 | nyrob
# Processing Record 481 | brokopondo
# Processing Record 482 | mandalgovi
# Processing Record 483 | port hedland
# Processing Record 484 | simplicio mendes
# Processing Record 485 | kattivakkam
# Processing Record 486 | college
# Processing Record 487 | hovd
# Processing Record 488 | elizabeth city
# Processing Record 489 | olafsvik
# Processing Record 490 | maxixe
# Processing Record 491 | longyearbyen
# City not found. Skipping...
# Processing Record 493 | vila velha
# Processing Record 494 | bambanglipuro
# Processing Record 495 | ossora
# Processing Record 496 | taremskoye
# Processing Record 497 | alyangula
# Processing Record 498 | tambopata
# Processing Record 499 | timizart
# Processing Record 500 | kimbe
# City not found. Skipping...
# Processing Record 502 | khorixas
# Processing Record 503 | sibu
# Processing Record 504 | poum
# Processing Record 505 | ballina
# Processing Record 506 | axim
# Processing Record 507 | gizo
# Processing Record 508 | mezen
# Processing Record 509 | humberto de campos
# Processing Record 510 | ndele
# Processing Record 511 | birao
# Processing Record 512 | ishigaki
# Processing Record 513 | carutapera
# Processing Record 514 | grindavik
# Processing Record 515 | thaba nchu
# Processing Record 516 | odweyne
# Processing Record 517 | kodinsk
# Processing Record 518 | sunrise manor
# Processing Record 519 | inhambane
# Processing Record 520 | saint-joseph
# Processing Record 521 | kota bahru
# Processing Record 522 | tavda
# City not found. Skipping...
# Processing Record 524 | guerrero negro
# Processing Record 525 | veseloyarsk
# City not found. Skipping...
# Processing Record 527 | alappuzha
# Processing Record 528 | kendari
# Processing Record 529 | biltine
# Processing Record 530 | meridian
# Processing Record 531 | aklavik
# Processing Record 532 | sitka
# Processing Record 533 | soure
# Processing Record 534 | boden
# Processing Record 535 | ovidiu
# Processing Record 536 | moranbah
# Processing Record 537 | eureka
# Processing Record 538 | westport
# Processing Record 539 | muisne
# Processing Record 540 | makinsk
# Processing Record 541 | talaya
# City not found. Skipping...
# Processing Record 543 | dicabisagan
# Processing Record 544 | mount isa
# Processing Record 545 | kharitonovo
# Processing Record 546 | solhan
# Processing Record 547 | avera
# Processing Record 548 | talara
# Processing Record 549 | marsh harbour
# Processing Record 550 | nuevo progreso
# Processing Record 551 | kasungu
# Processing Record 552 | broken hill
# Processing Record 553 | udachnyy
# Processing Record 554 | dashitou
# Processing Record 555 | toora-khem
# Processing Record 556 | bonavista
# Processing Record 557 | portales
# City not found. Skipping...
# Processing Record 559 | atambua
# Processing Record 560 | senador jose porfirio
# Processing Record 561 | la rioja
# Processing Record 562 | wahpeton
# Processing Record 563 | ourem
# Processing Record 564 | skjervoy
# City not found. Skipping...
# Processing Record 566 | roald
# Processing Record 567 | tulun
# Processing Record 568 | port macquarie
# Processing Record 569 | vostok
# Processing Record 570 | tomaszow lubelski
# Processing Record 571 | bosaso
# Processing Record 572 | owando
# Processing Record 573 | banda aceh
# Processing Record 574 | iralaya
# Processing Record 575 | coxim
# City not found. Skipping...
# Processing Record 577 | thames
# Processing Record 578 | omboue
# Processing Record 579 | mandan
# Processing Record 580 | moose factory
# Processing Record 581 | red bluff
# Processing Record 582 | kozhevnikovo
# Processing Record 583 | hobyo
# Processing Record 584 | tabuk
# Processing Record 585 | saint-quentin
# Processing Record 586 | altamira
# Processing Record 587 | fort nelson
# Processing Record 588 | ardakan
# Processing Record 589 | coro
# Processing Record 590 | nantucket
# Processing Record 591 | esso
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 594 | wasilla
# City not found. Skipping...
# Processing Record 596 | waspan
# Processing Record 597 | sladkovo
# City not found. Skipping...
# Processing Record 599 | flin flon
# Processing Record 600 | vao
# Processing Record 601 | north myrtle beach
# Processing Record 602 | leiyang
# Processing Record 603 | awjilah
# Processing Record 604 | acapulco
# Processing Record 605 | abnub
# Processing Record 606 | hauterive
# Processing Record 607 | santona
# Processing Record 608 | weymouth
# Processing Record 609 | metro
# Processing Record 610 | cloquet
# Processing Record 611 | ambilobe
# Processing Record 612 | mournies
# Processing Record 613 | ponta delgada
# Processing Record 614 | lucea
# Processing Record 615 | puerto madryn
# Processing Record 616 | puerto escondido
# Processing Record 617 | hohhot
# Processing Record 618 | catuday
# Processing Record 619 | cayambe
# Processing Record 620 | burnie
# Processing Record 621 | batagay
# Processing Record 622 | somerset
# Processing Record 623 | neiafu
# Processing Record 624 | waingapu
# Processing Record 625 | kokkola
# Processing Record 626 | rincon
# Processing Record 627 | hoquiam
# Processing Record 628 | belmonte
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df.replace("", "NaN", inplace=True)

weather_df["Cloudiness"] = weather_df["Cloudiness"].astype(float)
weather_df["Date"] = weather_df["Date"].astype(float)
weather_df["Humidity"] = weather_df["Humidity"].astype(float)
weather_df["Lat"] = weather_df["Lat"].astype(float)
weather_df["Lng"] = weather_df["Lng"].astype(float)
weather_df["Max Temp"] = weather_df["Max Temp"].astype(float)
weather_df["Wind Speed"] = weather_df["Wind Speed"].astype(float)

weather_df.dropna(inplace=True)

weather_df["Cloudiness"] = weather_df["Cloudiness"].astype(int)
weather_df["Humidity"] = weather_df["Humidity"].astype(int)

weather_df.reset_index(drop=True, inplace=True)

weather_df.index.name = "City_ID"

# %%
weather_df.count()
# Out:
# City          583
# Cloudiness    583
# Country       583
# Date          583
# Humidity      583
# Lat           583
# Lng           583
# Max Temp      583
# Wind Speed    583
# dtype: int64

# %%
# weather_df.to_csv("Cities.csv")
# weather_df.head()

# %%
weather_df.to_csv("Cities.csv")
weather_df.head()
# Out:
#                  City  Cloudiness Country          Date  Humidity    Lat  \
# City_ID
# 0                hilo          90      US  1.595707e+09        65  19.73
# 1              avarua          92      CK  1.595707e+09        69 -21.21
# 2             rikitea          16      PF  1.595707e+09        80 -23.12
# 3             bintulu          40      MY  1.595707e+09        94   3.17
# 4        saint george           1      US  1.595707e+09        22  37.10
#
#             Lng  Max Temp  Wind Speed
# City_ID
# 0       -155.09     82.40        6.93
# 1       -159.78     73.40        8.05
# 2       -134.97     69.62       21.18
# 3        113.03     77.00        3.36
# 4       -113.58     96.01        9.17

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %%
date = weather_df.loc[0, ["Date"]]
date2 = time.gmtime(date)
date3 = f"({date2[1]}/{date2[2]}/{date2[0]})"

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
weather_df.plot(kind = "scatter", x = "Lat", y ="Max Temp", title = 
               f"City Latitude VS Max Temperature{date3}", edgecolor = "pink" , s =50, alpha = 0.75)
plt.xlabel("Latitide")
plt.ylabel("Max Temperature (F)")
plt.grid()
plt.tight_layout()

# %%
plt.savefig("fig1_lat_tem.png")

# %% [markdown]
# Here the maximum temperature of a city on the 5th of April 2020 is plotted against the city's latitude. The trend shows that max temperatures decrease the farther from the equator the city is.

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
weather_df.plot(kind = "scatter", x = "Lat", y = "Humidity", title = 
               f"City Latitude VS Humidity {date3}", edgecolor = "purple", s = 50, alpha = 0.75)

plt.xlabel("Latitude")
plt.ylabel("Humdity(%)")
plt.grid()
plt.tight_layout()

# %%
plt.savefig("fig2_lat_hum.png")

# %% [markdown]
# Here the humidity of a city on the 5th of April 2020 is plotted against the city's latitude. There doesn't seem to be a strong trend between humidity and latitude.

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
weather_df.plot(kind = "scatter", x = "Lat", y ="Cloudiness", title = 
               f"City Latitude VS Cloudiness {date3}", edgecolor = "orange", s =50, alpha = 0.75)
plt.xlabel = ("Latitude")
plt.ylabel = ("Cloudiness (%)")
plt.grid()
plt.tight_layout()

# %%
plt.savefig("fig3_lat_cloud.png")

# %% [markdown]
# Here the cloudiness of a city on the 5th of April 2020 is plotted against the city's latitude. There seems to be horizontal lines along the easily divisible numbers weathermen like to forecast data on.

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
weather_df.plot(kind="scatter", x= "Lat", y = "Wind Speed", title =
               f"City Latitude  VS Wind Speed {date3}", edgecolor = "red", s= 50, alpha = 0.75)
plt.xlabel = ("Latitude")
plt.ylabel =("Wind Speed (mph)")
plt.grid()
plt.tight_layout()

# %%
plt.savefig("fig4_lat_wind.png")

# %% [markdown]
# Here the wind speed of a city on the 5th of April 2020 is charted against the city's latitude. It appears that higher wind speeds occur farther from the equator.

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames
Northern_hemisphere = weather_df.loc[weather_df["Lat"] >=0,:]
Northern_hemisphere.head()
# Out:
#                   City  Cloudiness Country          Date  Humidity    Lat  \
# City_ID
# 0                 hilo          90      US  1.595707e+09        65  19.73
# 3              bintulu          40      MY  1.595707e+09        94   3.17
# 4         saint george           1      US  1.595707e+09        22  37.10
# 5                kapaa          90      US  1.595707e+09        94  22.08
# 6        srednekolymsk           0      RU  1.595707e+09        31  67.45
#
#             Lng  Max Temp  Wind Speed
# City_ID
# 0       -155.09     82.40        6.93
# 3        113.03     77.00        3.36
# 4       -113.58     96.01        9.17
# 5       -159.32     78.01       14.99
# 6        153.68     79.97        3.83

# %%
Southern_hemisphere = weather_df.loc[weather_df["Lat"] <=0, :]
Southern_hemisphere.head()
# Out:
#                 City  Cloudiness Country          Date  Humidity    Lat  \
# City_ID
# 1             avarua          92      CK  1.595707e+09        69 -21.21
# 2            rikitea          16      PF  1.595707e+09        80 -23.12
# 7            ushuaia          40      AR  1.595707e+09        92 -54.80
# 11          hermanus           0      ZA  1.595707e+09        88 -34.42
# 12       new norfolk           6      AU  1.595707e+09        92 -42.78
#
#             Lng  Max Temp  Wind Speed
# City_ID
# 1       -159.78     73.40        8.05
# 2       -134.97     69.62       21.18
# 7        -68.30     30.20       20.80
# 11        19.23     57.00        1.01
# 12       147.06     39.00        2.62

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
Northern_hemisphere.plot(kind="scatter", x= "Lat", y = "Max Temp", title=
                        f"Northern Hemisphere City Latitude VS Max Temperature {date3}", edgecolor = "pink", s =40, alpha = 0.75)

plt.xlabel = ("Latitude")
plt.ylabel =("Max Temperature (F)")
plt.grid()
plt.tight_layout()

(slope, intercept, rvalue, pvalue, stderr) = linregress(Northern_hemisphere["Lat"], Northern_hemisphere["Max Temp"])

regress_values = Northern_hemisphere["Lat"] *slope+intercept

line_eq ="y=" + str(round(slope,2)) + "x+" +str(round(intercept,2))

plt.plot(Northern_hemisphere["Lat"], regress_values, "r-")
plt.annotate(line_eq, (5,40), fontsize = 18, color= "pink")



plt.show()

print(f"The r-squared is: {rvalue**2}.")
# Out:
# The r-squared is: 0.4866949124202201.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
Southern_hemisphere.plot(kind="scatter", x= "Lat", y = "Max Temp", title=
                        f"Southern Hemisphere City Latitude VS Max Temperature {date3}", edgecolor = "pink", s =40, alpha = 0.75)

plt.xlabel = ("Latitude")
plt.ylabel =("Max Temperature (F)")
plt.grid()
plt.tight_layout()

(slope, intercept, rvalue, pvalue, stderr) = linregress(Southern_hemisphere["Lat"], Southern_hemisphere["Max Temp"])

regress_values = Southern_hemisphere["Lat"] *slope+intercept

line_eq ="y=" + str(round(slope,2)) + "x+" + str(round(intercept,2))

plt.plot(Southern_hemisphere["Lat"], regress_values, "r-")
plt.annotate(line_eq, (-50,30), fontsize = 18, color= "red")


plt.show()

print(f"The r-squared is: {rvalue**2}.")
# Out:
# The r-squared is: 0.6847018074151171.

# %% [raw]
# Here cities in the southern hemisphere have their maximum temperature on April 5th 2020 charted against their latitude. The trend shows higher maximum temperatures closer to the equator.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
Northern_hemisphere.plot(kind="scatter", x= "Lat", y = "Humidity", title=
                        f"Northern Hemisphere City Latitude VS Humidity {date3}", edgecolor = "pink", s=50, alpha = 0.75)

plt.xlabel = ("Latitude")
plt.ylabel =("Humidity (%)")
plt.grid()
plt.tight_layout()

(slope, intercept, rvalue, pvalue, stderr) = linregress(Northern_hemisphere["Lat"], Northern_hemisphere["Humidity"])

regress_values = Northern_hemisphere["Lat"] *slope+intercept

line_eq ="y=" + str(round(slope,2)) + "x+" +str(round(intercept,2))

plt.plot(Northern_hemisphere["Lat"], regress_values, "r-")
plt.annotate(line_eq, (5,40), fontsize = 18, color= "pink")



plt.show()

print(f"The r-squared is: {rvalue**2}.")
# Out:
# The r-squared is: 0.012428060961776314.

# %% [raw]
# Here cities in the northern hemisphere have their humidity on April 5th 2020 charted against their latitude. There doesn't seem to be a strong trend between humidity and latitude.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
Southern_hemisphere.plot(kind="scatter", x= "Lat", y = "Humidity", title=
                        f"Southern Hemisphere City Latitude VS Humidity {date3}", edgecolor = "pink", s =40, alpha = 0.75)

plt.xlabel = ("Latitude")
plt.ylabel =("Humidity (%)")
plt.grid()
plt.tight_layout()

(slope, intercept, rvalue, pvalue, stderr) = linregress(Southern_hemisphere["Lat"], Southern_hemisphere["Humidity"])

regress_values = Southern_hemisphere["Lat"] *slope+intercept

line_eq ="y=" + str(round(slope,2)) + "x+" + str(round(intercept,2))

plt.plot(Southern_hemisphere["Lat"], regress_values, "r-")
plt.annotate(line_eq, (-50,30), fontsize = 18, color= "red")


plt.show()

print(f"The r-squared is: {rvalue**2}.")
# Out:
# The r-squared is: 0.013926656242384752.

# %% [raw]
# Here cities in the southern hemisphere have their humidity on April 5th 2020 charted against their latitude. There doesn't seem to be a strong trend between latitude and humidity.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
Northern_hemisphere.plot(kind="scatter", x= "Lat", y = "Cloudiness", title=
                        f"Northern Hemisphere City Latitude VS Cloudiness {date3}", edgecolor = "pink", s =40, alpha = 0.75)

plt.xlabel = ("Latitude")
plt.ylabel =("Cloudiness (%)")
plt.grid()
plt.tight_layout()

(slope, intercept, rvalue, pvalue, stderr) = linregress(Northern_hemisphere["Lat"], Northern_hemisphere["Cloudiness"])

regress_values = Northern_hemisphere["Lat"] *slope+intercept

line_eq ="y=" + str(round(slope,2)) + "x+" +str(round(intercept,2))

plt.plot(Northern_hemisphere["Lat"], regress_values, "r-")
plt.annotate(line_eq, (5,40), fontsize = 18, color= "pink")



plt.show()

print(f"The r-squared is: {rvalue**2}.")
# Out:
# The r-squared is: 0.0015459088842198613.

# %% [raw]
# Here cities in the northern hemisphere have their cloud coverage on April 5th 2020 plotted against their latitude. There seems to be horizontal groupings of data along easily chosen estimates for cloud coverage.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
Southern_hemisphere.plot(kind="scatter", x= "Lat", y = "Cloudiness", title=
                        f"Southern Hemisphere City Latitude VS Cloudiness {date3}", edgecolor = "pink", s =40, alpha = 0.75)

plt.xlabel = ("Latitude")
plt.ylabel =("Cloudiness (%)")
plt.grid()
plt.tight_layout()

(slope, intercept, rvalue, pvalue, stderr) = linregress(Southern_hemisphere["Lat"], Southern_hemisphere["Cloudiness"])

regress_values = Southern_hemisphere["Lat"] *slope+intercept

line_eq ="y=" + str(round(slope,2)) + "x+" + str(round(intercept,2))

plt.plot(Southern_hemisphere["Lat"], regress_values, "r-")
plt.annotate(line_eq, (-50,30), fontsize = 18, color= "red")


plt.show()

print(f"The r-squared is: {rvalue**2}.")
# Out:
# The r-squared is: 0.001546478997722135.

# %% [raw]
# Here cities in the southern hemisphere have their cloud coverage on April 5th 2020 plotted against their latitude. There doesn't seem to be a strong correlation between cloudiness and latitude.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
Northern_hemisphere.plot(kind="scatter", x= "Lat", y = "Wind Speed", title=
                        f"Northern Hemisphere City Latitude VS Wind Speed {date3}", edgecolor = "pink", s=50, alpha = 0.75)

plt.xlabel = ("Latitude")
plt.ylabel =("Wind Speed (mph)")
plt.grid()
plt.tight_layout()

(slope, intercept, rvalue, pvalue, stderr) = linregress(Northern_hemisphere["Lat"], Northern_hemisphere["Wind Speed"])

regress_values = Northern_hemisphere["Lat"] *slope+intercept

line_eq ="y=" + str(round(slope,2)) + "x+" +str(round(intercept,2))

plt.plot(Northern_hemisphere["Lat"], regress_values, "r-")
plt.annotate(line_eq, (5,40), fontsize = 18, color= "pink")



plt.show()

print(f"The r-squared is: {rvalue**2}.")
# Out:
# The r-squared is: 0.0004455527826215732.

# %% [raw]
# Here cities in the northern hemisphere have their wind speed on April 5th 2020 charted against their latitude. There seems to be higher wind speeds farther from the equator.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
Southern_hemisphere.plot(kind="scatter", x= "Lat", y = "Wind Speed", title=
                        f"Southern Hemisphere City Latitude VS Wind Speed {date3}", edgecolor = "pink", s =40, alpha = 0.75)

plt.xlabel = ("Latitude")
plt.ylabel =("Wind Speed(mph)")
plt.grid()
plt.tight_layout()

(slope, intercept, rvalue, pvalue, stderr) = linregress(Southern_hemisphere["Lat"], Southern_hemisphere["Wind Speed"])

regress_values = Southern_hemisphere["Lat"] *slope+intercept

line_eq ="y=" + str(round(slope,2)) + "x+" + str(round(intercept,2))

plt.plot(Southern_hemisphere["Lat"], regress_values, "r-")
plt.annotate(line_eq, (-50,30), fontsize = 18, color= "red")


plt.show()

print(f"The r-squared is: {rvalue**2}.")
# Out:
# The r-squared is: 0.0024818534111577264.

# %% [raw]
# Here cities in the southern hemisphere have their wind speed on April 5th 2020 plotted against their latitude. There seems to be higher wind speeds farther from the equator.
